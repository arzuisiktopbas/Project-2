# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
from finvizfinance.screener.overview import Overview
import alpaca_trade_api as tradeapi
import datetime
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
import arch
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Read your api key environment variable
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("news_api")
print(api_key)
# Out:
# f147b186a1504298a5fca6370fdcfe78

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=os.environ["news_api"])

# %%
foverview = Overview()

filters_dict = {
    'Performance':'Today Up',
    'Current Volume':"Over 10M",
    'Change': 'Up 5%',
    'Country': 'USA'
}
foverview.set_filter(filters_dict=filters_dict)

tickers = foverview.ScreenerView()
#tickers.sort_values(by='Volume', inplace=True, ascending=False)
tickers.set_index('Ticker', inplace=True )
tickers.head(100)
# Out:
# [Info] loading page [##############################] 3/3
#                                             Company                  Sector  \
# Ticker
# AACQ                        Artius Acquisition Inc.               Financial
# AGTC       Applied Genetic Technologies Corporation              Healthcare
# AKER                        Akers Biosciences, Inc.              Healthcare
# ALJJ                    ALJ Regional Holdings, Inc.             Industrials
# APA                              Apache Corporation                  Energy
# AR                     Antero Resources Corporation                  Energy
# ASRT                        Assertio Holdings, Inc.              Healthcare
# BNGO                         Bionano Genomics, Inc.              Healthcare
# BOXL                           Boxlight Corporation              Technology
# CCIV                      Churchill Capital Corp IV               Financial
# CCL                      Carnival Corporation & plc       Consumer Cyclical
# CEI                             Camber Energy, Inc.                  Energy
# CFMS                                Conformis, Inc.              Healthcare
# COTY                                      Coty Inc.      Consumer Defensive
# CSCW                Color Star Technology Co., Ltd.  Communication Services
# CTXR                   Citius Pharmaceuticals, Inc.              Healthcare
# DFFN                 Diffusion Pharmaceuticals Inc.              Healthcare
# DPW                      Ault Global Holdings, Inc.             Industrials
# FCX                           Freeport-McMoRan Inc.         Basic Materials
# GHSI                 Guardion Health Sciences, Inc.              Healthcare
# HOFV    Hall of Fame Resort & Entertainment Company  Communication Services
# INPX                                        Inpixon              Technology
# ISR                                    Isoray, Inc.              Healthcare
# KOPN                              Kopin Corporation              Technology
# MARA                    Marathon Patent Group, Inc.               Financial
# MICT                                     MICT, Inc.              Technology
# MRO                        Marathon Oil Corporation                  Energy
# MVIS                              MicroVision, Inc.              Technology
# NCLH            Norwegian Cruise Line Holdings Ltd.       Consumer Cyclical
# NMTR                       9 Meters Biopharma, Inc.              Healthcare
# NVIV             InVivo Therapeutics Holdings Corp.              Healthcare
# OCGN                                   Ocugen, Inc.              Healthcare
# OEG                      Orbital Energy Group, Inc.               Utilities
# ONTX                    Onconova Therapeutics, Inc.              Healthcare
# PAVM                                    PAVmed Inc.              Healthcare
# PINS                                Pinterest, Inc.  Communication Services
# RIOT                          Riot Blockchain, Inc.              Technology
# SAVA                         Cassava Sciences, Inc.              Healthcare
# SCKT                            Socket Mobile, Inc.              Technology
# SENS                      Senseonics Holdings, Inc.              Healthcare
# SESN                                Sesen Bio, Inc.              Healthcare
# SONM                       Sonim Technologies, Inc.              Technology
# TLGT                                 Teligent, Inc.              Healthcare
# TMBR                   Timber Pharmaceuticals, Inc.              Healthcare
# UAMY            Other Industrial Metals & Mining     USA  1.522600e+08  None
# UEC                                      Uranium     USA  4.540200e+08  None
# URG                                      Uranium     USA  2.479200e+08  None
# USWS                         Oil & Gas Midstream     USA  1.645700e+08  None
# X                                          Steel     USA  5.020000e+09  None
# XSPA                           Personal Services     USA  2.701200e+08  None
#
#         Price  Change       Volume
# Ticker
# AACQ    14.00  0.2422   14124270.0
# AGTC     8.07  0.3058   26850803.0
# AKER     4.82  0.2853   11034143.0
# ALJJ     2.03  0.5263   70214866.0
# APA     18.58  0.0629   10896048.0
# AR       9.49  0.0544   16513727.0
# ASRT     1.22  0.0702   35811994.0
# BNGO    15.57  0.1365   54738170.0
# BOXL     3.60  0.1465   10383204.0
# CCIV    52.70  0.3182   95561320.0
# CCL     22.47  0.0908   54542613.0
# CEI      2.18  0.1848   15888809.0
# CFMS     1.18  0.0536   10984418.0
# COTY     7.18  0.0590   21620557.0
# CSCW     1.33  0.1565   15538001.0
# CTXR     1.69  0.2426   31928991.0
# DFFN     1.70  0.3710  106592258.0
# DPW      6.24  0.1025   19644360.0
# FCX     32.90  0.0535   28666766.0
# GHSI     1.16  0.0545   19712774.0
# HOFV     2.74  0.0538   10307750.0
# INPX     2.11  0.0657   20861958.0
# ISR      1.77  0.0663   11121378.0
# KOPN    13.56  0.2509   12866387.0
# MARA    43.56  0.1326   28456947.0
# MICT     2.58  0.1727  115133990.0
# MRO      9.55  0.0647   26783900.0
# MVIS    23.72  0.2941   25330021.0
# NCLH    25.19  0.0701   22637705.0
# NMTR     2.16  0.0964   10438971.0
# NVIV     1.78  0.1338   15440898.0
# OCGN    10.96  0.0661   26565845.0
# OEG      9.86  0.1641   11441085.0
# ONTX     1.22  0.0517   49275638.0
# PAVM     4.49  0.2829   14163431.0
# PINS    89.15  0.0608   18119527.0
# RIOT    59.50  0.2074   42513136.0
# SAVA    51.83  0.1238   12364880.0
# SCKT    20.68  5.3827  226191717.0
# SENS     5.27  0.2668   86568440.0
# SESN     3.02  0.0786   36377910.0
# SONM     1.56  0.3220   15921466.0
# TLGT     1.36  0.1333   12527493.0
# TMBR     3.06  0.3021   22585556.0
# TRCH     4.29  0.5053  255079527.0
# UAMY     1.68  0.0566   16214147.0
# UEC      2.42  0.0708   10522374.0
# URG      1.37  0.1913   14974851.0
# USWS     2.08  0.4150   16629083.0
# X       18.48  0.1200   27461350.0
# XSPA     2.83  0.0560   20053601.0

# %%
def get_sentiment(company):
    stock_headlines = ( newsapi.get_everything(
    q=company,
    language='en',
    sort_by='relevancy'))

    sentiments = []

    for articles in stock_headlines['articles']:
        try:
            text = articles['content']
            results = analyzer.polarity_scores(text)
            compound = results['compound']
            pos = results['pos']
            neu = results['neu']
            neg = results['neg'] 

            #put data into sentiments
            sentiments.append({
                'text':text,
                'Compound':compound,
                'Positive':pos,
                'Negative':neg,
                'Neutral':neu})

        except AttributeError:
            pass
    fininal_sentiments = pd.DataFrame(sentiments)
    if not fininal_sentiments.empty:
        return(fininal_sentiments["Positive"].mean())
    else:
        return(0)

# %%
ticker_sentiment = [] 
for ticker in tickers.index: 
    sentiment = get_sentiment(tickers['Company'][ticker])
    print(sentiment)
    if float(sentiment) >= 0.1:
        ticker_sentiment.append(ticker)
        print(f"{ticker} meets our sentiment requirement")
    else:
        print(f"{ticker} does not meet our sentiment requirement")
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# <ipython-input-120-ddb467004c31> in <module>
#       1 ticker_sentiment = []
#       2 for ticker in tickers.index:
# ----> 3     sentiment = get_sentiment(tickers['Company'][ticker])
#       4     print(sentiment)
#       5     if float(sentiment) >= 0.1:
#
# <ipython-input-119-dbf466fbf439> in get_sentiment(company)
#       3     q=company,
#       4     language='en',
# ----> 5     sort_by='relevancy'))
#       6
#       7     sentiments = []
#
# ~/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/newsapi/newsapi_client.py in get_everything(self, q, qintitle, sources, domains, exclude_domains, from_param, to, language, sort_by, page, page_size)
#     324         # Check Status of Request
#     325         if r.status_code != requests.codes.ok:
# --> 326             raise NewsAPIException(r.json())
#     327
#     328         return r.json()
#
# NewsAPIException: {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}

# %%
### Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version = "v2"
)

# %%
#Set time frame for reporting stocks
today = datetime.date.today()
tomorrow = today + datetime.timedelta(days = 2) 
start_time = tomorrow.strftime("%b %d %Y") + " 10:00AM"
next_day = today + datetime.timedelta(days = 1) 
end_time = next_day.strftime("%b %d %Y") + " 1:00PM"

date_from = datetime.datetime.strptime(
    start_time, '%b %d %Y %I:%M%p')
date_to = datetime.datetime.strptime(
    end_time, '%b %d %Y %I:%M%p')

# %%
# Set timeframe to '1D'
timeframe = "1D"

#Set timeframe for last 2 years
start_date = pd.Timestamp("2018-05-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp(next_day, tz="America/New_York").isoformat()

#Get ticker data
df_ticker = api.get_barset(
    ticker_sentiment,
    timeframe,
    start=start_date,
    end=end_date
).df

df_ticker.dropna()
df_ticker.tail()

# %%
df_closing_prices = pd.DataFrame()
for ticker in ticker_sentiment: 
    df_closing_prices[ticker] = df_ticker[ticker]["close"]

# %%
df_closing_prices.head()

# %%
def hpfilter(ticker):
    ts_noise, ts_trend = sm.tsa.filters.hpfilter(df_ticker[ticker][['close']])

    #create different dataframes for each composition
    ticker_decomp = df_ticker[ticker][['close']].copy()
    ticker_decomp['noise'] = ts_noise
    ticker_decomp['trend'] = ts_trend
    return ts_noise.plot(title='Noise')

# %%
for ticker in ticker_sentiment: 
    print(hpfilter((ticker)))

# %%
from statsmodels.tsa.arima_model import ARIMA
for ticker in df_closing_prices: 
    model = ARIMA(df_closing_prices[ticker], order=(1,1,1))
    results = model.fit()
    pd.DataFrame(results.forecast(steps=5)[1]).plot(title=f'Forcast {ticker} ARIMA next 5 days')
    print(results.summary())

# %%
#Print Graphs
pd.DataFrame(results.forecast(steps=5)[0]).plot(title=f'Forcast {ticker} ARIMA next 5 days')
